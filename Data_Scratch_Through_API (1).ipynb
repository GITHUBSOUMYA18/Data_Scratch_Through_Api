# %%
import pandas as pd
import requests

# %%
# Movie Recomnedation
# Website_link = (https://www.themoviedb.org/)

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6c151710afc0c3113b07023f306a2690&language=en-US&page=1%27")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 160.271,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.706,
#    'vote_count': 26715},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
df = pd.DataFrame(response.json()["results"])[["id","title","overview","release_date","popularity","vote_average","vote_count"]]
df
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5       129                                  Spirited Away
# 6     19404                    Dilwale Dulhania Le Jayenge
# 7       155                                The Dark Knight
# 8    496243                                       Parasite
# 9       497                                 The Green Mile
# 10      680                                   Pulp Fiction
# 11   372058                                     Your Name.
# 12      122  The Lord of the Rings: The Return of the King
# 13       13                                   Forrest Gump
# 14      769                                     GoodFellas
# ...

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     160.271
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     161.600
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     102.054
# 3  The true story of how businessman Oskar Schind...   1993-12-15      99.498
# 4  The defense and the prosecution have rested an...   1957-04-10      63.081
#
#    vote_average  vote_count
# 0         8.706       26715
# 1         8.690       20274
# 2         8.574       12229
# 3         8.566       15638
# 4         8.544        8475

# %%
df.shape
# Out:
# (20, 7)

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,480):
  response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=6c151710afc0c3113b07023f306a2690&language=en-US&page={}%27".format(i))
  temp_df=pd.DataFrame(response.json()["results"])[["id","title","overview","release_date","popularity","vote_average","vote_count"]]
  df = pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#            id                     title  \
# 0         278  The Shawshank Redemption
# 1         238             The Godfather
# 2         240     The Godfather Part II
# 3         424          Schindler's List
# 4         389              12 Angry Men
# ...       ...                       ...
# 12355    7278         Meet the Spartans
# 12356   17473                  The Room
# 12357    8046                     Gigli
# 12358  505423                    Wounds
# 12359  419507        Fuga da Reuma Park
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# 4      The defense and the prosecution have rested an...   1957-04-10
# ...

# %%
df.to_csv("Movies_Own(fetch).csv")
